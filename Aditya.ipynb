# %%
import pandas as pd

# %%
df=pd.read_excel('Assignment Day 1(1).xlsx')

# %%
df
# Out:
#     Unnamed: 0 Unnamed: 1                                         Unnamed: 2  \
# 0          NaN        NaN  Create a summary Data Analysis about the datas...
# 1          NaN        NaN         Use Name Range concept to apply functions.
# 2          NaN        NaN                                                NaN
# 3          NaN        NaN                                                NaN
# 4          NaN     C_Code                                          FirstName
# 5          NaN     150834                                                Ram
# 6          NaN     150784                                             Sachin
# 7          NaN     150791                                             Rajesh
# 8          NaN     150940                                            Rajeesh
# 9          NaN     150777                                             Melwyn
# 10         NaN     150805                                             Rajesh
# ...
